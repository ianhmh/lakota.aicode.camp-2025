# %% [markdown]
# ## Collecting Language Data From Ourselves

# %% [markdown]
# ### Setting Up Our Recording Environment

# %% [markdown]
# 1. Consider the sounds in your recording environment. Will your recordings pick up other sounds? Is that ok?
#
# 1. We will use an application that comes with Windows 11 called `Sound Recorder`.
#
# 1. You will want to save your audio files in the `.wav` format. Complete the following steps to ensure that your data will be saved correctly.
#     1. Open `Sound Recorder`
#     1. Click on the three dots (`...`) in the upper right corner and select the `Settings` option.
#     ![image.png](attachment:image.png)
#     1. In the `Settings`, expand the `Recording format` menu and select the `WAV (lossless)` option.
#     ![image-2.png](attachment:image-2.png)
#
# 1. *(Optional)* You may want to use high, or low, quality data. I will leave it up to you to try out different options if you want. The default setting is `Auto`.
#
# 1. Exit the `Settings` and then select your microphone. Your computer comes with a microphone, but you may want to use your earbuds, or an external microphone. This can be changed in the bottom left corner of the main window. In the example below, I have my bluetooth headphones selected.
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Recording Audio

# %% [markdown]
# You should now be all set to record multiple clips of the same phrase or word. The model we will train will look at the entire recording, so if you record phrases, it will try to classify the recordings as that whole phrase.
# You will want to record the same phrase (or word) (or class) many times. They may sound the same to you, but there will be important differences that we will need to create a useful model.
#
# **Record at least 20 of each phrase/word on this first go around.**

# %% [markdown]
# ### Renaming and Organizing Audio Files

# %% [markdown]
# After recording each phrase/word, we should rename the files and place them in a labeled directory. Keeping our audio files organized is essential.
#
# 1. In `Sound Recorder`, `right-click` on one of your recordings and select the `Show in folder` option. This will open up the folder where the recordings are currently stored.
# ![image.png](attachment:image.png)
#
# 1. Select all of the files, `right-click` on one of the files and select the option `Rename with PowerRename`.
#
# 1. In the `PowerRename` window that opens, use the following settings.
#     - In the `Search for` text box, enter `Recording(?: \((\d+)\))?\.wav`.
#     - Check the box labeled `Use regular expressions`.
#     - In the `Replace with` text box, enter `name_${1:1}.wav`, where `name` is the label you want to use for the class of words.
#     ![image-2.png](attachment:image-2.png)
#
# 1. Press the `Apply` button on the bottom and your files will automatically be renamed.
#
# 1. Finally, move all of the files into a folder with the correct label. In the example below, I've moved all the files into a folder labeled `red` because I recorded the Lakota word for red.
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Get Lot's of Data

# %% [markdown]
# Continue recording, renaming, and organizing your data.
